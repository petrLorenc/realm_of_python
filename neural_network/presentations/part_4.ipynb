# %%
from __future__ import annotations
# %matplotlib inline

# %%
def display_tree_visualization_of_node(node: Value, prefix="", is_last=True):
    """Display a tree-like visualization of the computational graph."""
    if prefix == "":  # Root node
        print(f"Result: {node.data}")
        print()
        connector = ""
    else:
        connector = "└── " if is_last else "├── "

    print(f"{prefix}{connector}{node.data:<4.2f} ({node._op}, grad:{node.grad:.10f}, id:{node._id}, name='{node._name}')")

    # Set the prefix for the next level
    child_prefix = prefix + ("    " if is_last else "│   ")

    # Process children
    children = list(sorted(node._children))
    for i, child in enumerate(children):
        is_last_child = (i == len(children) - 1)
        display_tree_visualization_of_node(child, child_prefix, is_last_child)

# %%
import math
import numpy as np


# we need to look at backward pass of the neuron

# for backward
# let's apply the rules from https://www.mathsisfun.com/calculus/derivatives-rules.html

class Value:
    def __init__(self, data, _children: tuple = None, *, op='leaf', _backward=lambda: None, name=""):
        self.data: float = data
        self._children: set = set() if _children is None else set(_children)
        self._op: str = op
        self.grad: float = 0.0  # Gradient initialized to zero
        self._id: int = id(self)  # Unique identifier for the node, useful for debugging
        self._name: str = name  # Name of the node for better visualization

        self._backward: callable = _backward

    def backward(self):
        # check if I am the root node (level 0), then it will be preset to 1.0
        # topological order all of the children in the graph
        topo = []
        visited = set()
        def build_topo(vertex):
            if vertex not in visited:
                visited.add(vertex)
                for child in vertex._children:
                    build_topo(child)
                topo.append(vertex)
        build_topo(self)

        # go one variable at a time and apply the chain rule to get its gradient
        self.grad = 1
        for v in reversed(topo):
            v._backward()

    def __repr__(self):
        return f"Value(data={self.data}, op='{self._op}', id={self._id}, name='{self._name}', grad='{self.grad}')"

    def __add__(self, other):
        if isinstance(other, int) or isinstance(other, float):
            other = Value(other)

        child_a = self
        child_b = other

        result = Value(self.data + other.data, (child_a, child_b), op='+')

        def _backward():
            child_a.grad += 1 * result.grad
            child_b.grad += 1 * result.grad

        result._backward = _backward

        return result

    def __mul__(self, other):
        if isinstance(other, int) or isinstance(other, float):
            other = Value(other)

        child_a = self
        child_b = other

        result = Value(self.data * other.data, (child_a, child_b), op='*')

        def _backward():
            child_a.grad += child_b.data * result.grad
            child_b.grad += child_a.data * result.grad

        result._backward = _backward
        return result

    def __neg__(self):
        return self.data * -1

    def __sub__(self, other):
        return self + (-other)

    def __rmul__(self, other):
        """Fallback - Solve the case where Value is on the right side of the multiplication operator."""
        return self * other

    def __radd__(self, other):
        """Fallback - Solve the case where Value is on the right side of the addition operator."""
        return self + other

    def __truediv__(self, other): # self / other
        return self * other**-1

    def __rtruediv__(self, other): # other / self
        return other * self**-1

    def __pow__(self, power, modulo=None):
        child = self

        result = Value(self.data ** power, (child,), op="**")

        def _backward():
            # taken from https://www.symbolab.com/cheat-sheets/Derivatives#
            child.grad += power * (child.data ** (power - 1)) * result.grad

        result._backward = _backward
        return result

    def relu(self):
        child = self

        result = Value(0 if child.data < 0 else child.data, (child,), op='ReLU')

        def _backward():
            child.grad += (result.data > 0) * result.grad

        result._backward = _backward

        return result

    def sigmoid(self):
        child = self

        result = Value(1 / (1 + np.exp(-child.data)), (child,), op='sigmoid')

        def _backward():
            # https://en.wikipedia.org/wiki/Logistic_function
            child.grad += result.data * (1 - result.data) * result.grad

        result._backward = _backward

        return result

    def exp(self):
        child = self

        result = Value(math.exp(child.data), (child,), op='exp')

        def _backward():
            child.grad += result.data * result.grad

        result._backward = _backward

        return result


    def __lt__(self, other):
        return self._id < other._id

# %%
a = Value(2.0, name="a")
b = Value(3.0, name="b")
c = Value(10.0, name="c")

result = a * b + c + 2
# result = result.relu()
result.backward() # Calculate gradients
display_tree_visualization_of_node(result)
# Out:
# Result: 18.0
#
# 18.00 (+, grad:1.0000000000, id:4660096784, name='')
#     ├── 2.00 (leaf, grad:1.0000000000, id:4658532944, name='')
#     └── 16.00 (+, grad:1.0000000000, id:4660683760, name='')
#         ├── 6.00 (*, grad:1.0000000000, id:4660684672, name='')
#         │   ├── 3.00 (leaf, grad:2.0000000000, id:4623001680, name='b')
#         │   └── 2.00 (leaf, grad:3.0000000000, id:4660050784, name='a')
#         └── 10.00 (leaf, grad:1.0000000000, id:4661100624, name='c')

# %%
a = Value(2.0, name="a")
b = Value(3.0, name="b")
c = Value(10.0, name="c")

result: Value = a * b + c + 2
result = result.sigmoid()
# result = result.relu()
# result = result.exp()
result.backward() # Calculate gradients
display_tree_visualization_of_node(result)
# Out:
# Result: 0.9999999847700205
#
# 1.00 (sigmoid, grad:1.0000000000, id:4892518432, name='')
#     └── 18.00 (+, grad:0.0000000152, id:4896097232, name='')
#         ├── 16.00 (+, grad:0.0000000152, id:4895071824, name='')
#         │   ├── 6.00 (*, grad:0.0000000152, id:4895073744, name='')
#         │   │   ├── 2.00 (leaf, grad:0.0000000457, id:4894979712, name='a')
#         │   │   └── 3.00 (leaf, grad:0.0000000305, id:4896397904, name='b')
#         │   └── 10.00 (leaf, grad:0.0000000152, id:4896399696, name='c')
#         └── 2.00 (leaf, grad:0.0000000152, id:4895896336, name='')

# %%
# how to get all parameters?

# now let's look at neuron
# https://www.bing.com/images/search?q=neuron+math&form=HDRSC4&first=1
import random
random.seed(42)

class Neuron:
    def __init__(self, weights, bias=0.0):
        self.weights = [Value(random.uniform(-1, 1)) if not x else Value(x) for x in weights]
        self.bias = Value(bias if bias else random.uniform(-1, 1))

    def forward(self, neuron_inputs):
        assert len(neuron_inputs) == len(self.weights), "Input size must match weights size"
        weighted_sum = self.weights[0] * neuron_inputs[0]
        for w, i in zip(self.weights[1:], neuron_inputs[1:]):
            weighted_sum += (w * i)
        output = weighted_sum + self.bias
        return output.sigmoid()

    def __call__(self, *args, **kwargs):
        return self.forward(*args)

    def parameters(self):
        """Return all parameters of the neuron (weights and bias)."""
        return self.weights + [self.bias]

    def zero_grad(self):
        """Set all gradients of the neuron to zero."""
        for w in self.weights:
            w.grad = 0.0
        self.bias.grad = 0.0

class Layer:
    def __init__(self, n_in, n_out):
        self.neurons = [Neuron([None] * n_in) for _ in range(n_out)]

    def forward(self, layer_inputs):
        outputs = [neuron(layer_inputs) for neuron in self.neurons]
        return outputs

    def __call__(self, *args, **kwargs):
        return self.forward(*args)

    def parameters(self):
        """Return all parameters of the layer (weights and biases of all neurons)."""
        params = []
        for neuron in self.neurons:
            params.extend(neuron.parameters())
        return params

    def zero_grad(self):
        """Set all gradients of the layer's neurons to zero."""
        for neuron in self.neurons:
            neuron.zero_grad()

class MLP:
    def __init__(self, n_in: int, internal_dims: list):
        dimensions = [n_in] + internal_dims
        self.layers = [Layer(dimensions[i], dimensions[i + 1]) for i in range(len(dimensions) - 1)]

    def forward(self, mlp_inputs):
        mlp_inputs = [Value(x) if not isinstance(x, Value) else x for x in mlp_inputs]  # Convert inputs to Value objects
        for layer in self.layers:
            print(mlp_inputs)
            mlp_inputs = layer.forward(mlp_inputs)
        return mlp_inputs if len(mlp_inputs) != 1 else mlp_inputs[0]

    def __call__(self, *args, **kwargs):
        return self.forward(*args)

    def parameters(self):
        """Return all parameters of the MLP (weights and biases of all layers)."""
        params = []
        for layer in self.layers:
            params.extend(layer.parameters())
        return params

    def zero_grad(self):
        """Set all gradients of the MLP's layers to zero."""
        for layer in self.layers:
            layer.zero_grad()

# %%
np.random.seed(42)

train_x = [
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
]

train_y = [
    [0],
    [1],
    [1],
    [0]
]

mlp = MLP(n_in=2, internal_dims=[2, 1])

print(mlp.forward(train_x[0]))
print(mlp.forward(train_x[1]))
print(mlp.forward(train_x[2]))
print(mlp.forward(train_x[3]))
print()

for epoch in range(10000):
    mlp.zero_grad()  # Reset gradients before each epoch
    overall_loss = None
    for i in range(len(train_x)):
        inputs = train_x[i]
        target = train_y[i]

        outputs = mlp(inputs)  # Forward pass
        if overall_loss is None:
            overall_loss = (outputs - target[0]) ** 2  # Mean Squared Error
        else:
            overall_loss += (outputs - target[0]) ** 2  # Mean Squared Error - Accumulate loss

    overall_loss.backward()  # Backward pass to compute gradients

    # Update parameters using gradient descent
    learning_rate = 0.1
    for param in mlp.parameters():
        param.data -= learning_rate * param.grad

print(mlp.forward(train_x[0]))
print(mlp.forward(train_x[1]))
print(mlp.forward(train_x[2]))
print(mlp.forward(train_x[3]))
# Out:
# [Value(data=0, op='leaf', id=4661314384, name='', grad='0.0'), Value(data=0, op='leaf', id=4660664944, name='', grad='0.0')]
# [Value(data=0.38937470755111603, op='sigmoid', id=4661376208, name='', grad='0.0'), Value(data=0.5874415780754889, op='sigmoid', id=4661265104, name='', grad='0.0')]
# Value(data=0.4167704251711119, op='sigmoid', id=4661265744, name='', grad='0.0')
# [Value(data=0, op='leaf', id=4661265872, name='', grad='0.0'), Value(data=1, op='leaf', id=4661266000, name='', grad='0.0')]
# [Value(data=0.19782882989705186, op='sigmoid', id=4661266640, name='', grad='0.0'), Value(data=0.6955807834931, op='sigmoid', id=4661267280, name='', grad='0.0')]
# Value(data=0.3599405159557011, op='sigmoid', id=4661267920, name='', grad='0.0')
# [Value(data=1, op='leaf', id=4661268048, name='', grad='0.0'), Value(data=0, op='leaf', id=4661268176, name='', grad='0.0')]
# [Value(data=0.45733208546958715, op='sigmoid', id=4661268816, name='', grad='0.0'), Value(data=0.45012156176767953, op='sigmoid', id=4661269456, name='', grad='0.0')]
# Value(data=0.4577759954549402, op='sigmoid', id=4661270096, name='', grad='0.0')
# [Value(data=1, op='leaf', id=4661270224, name='', grad='0.0'), Value(data=1, op='leaf', id=4661270352, name='', grad='0.0')]
# [Value(data=0.24581355759616041, op='sigmoid', id=4661270992, name='', grad='0.0'), Value(data=0.5677710617066698, op='sigmoid', id=4661271632, name='', grad='0.0')]
# Value(data=0.39355371224234603, op='sigmoid', id=4661272272, name='', grad='0.0')
#
# [Value(data=0, op='leaf', id=4661272400, name='', grad='0.0'), Value(data=0, op='leaf', id=4661272528, name='', grad='0.0')]
# [Value(data=0.38937470755111603, op='sigmoid', id=4661273168, name='', grad='0.0'), Value(data=0.5874415780754889, op='sigmoid', id=4661273808, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661274960, name='', grad='0.0'), Value(data=1, op='leaf', id=4661275088, name='', grad='0.0')]
# [Value(data=0.19782882989705186, op='sigmoid', id=4661275728, name='', grad='0.0'), Value(data=0.6955807834931, op='sigmoid', id=4661276368, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661277648, name='', grad='0.0'), Value(data=0, op='leaf', id=4661277776, name='', grad='0.0')]
# [Value(data=0.45733208546958715, op='sigmoid', id=4661278416, name='', grad='0.0'), Value(data=0.45012156176767953, op='sigmoid', id=4661279056, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661272016, name='', grad='0.0'), Value(data=1, op='leaf', id=4661271760, name='', grad='0.0')]
# [Value(data=0.24581355759616041, op='sigmoid', id=4661271376, name='', grad='0.0'), Value(data=0.5677710617066698, op='sigmoid', id=4661270864, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661268816, name='', grad='0.0'), Value(data=0, op='leaf', id=4661269328, name='', grad='0.0')]
# [Value(data=0.38994562819886397, op='sigmoid', id=4661268048, name='', grad='0.0'), Value(data=0.5867633285616094, op='sigmoid', id=4661267920, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661266896, name='', grad='0.0'), Value(data=1, op='leaf', id=4661266768, name='', grad='0.0')]
# [Value(data=0.1983593685174727, op='sigmoid', id=4661266256, name='', grad='0.0'), Value(data=0.6947016687294758, op='sigmoid', id=4661265232, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661280336, name='', grad='0.0'), Value(data=0, op='leaf', id=4661280464, name='', grad='0.0')]
# [Value(data=0.4585505988523449, op='sigmoid', id=4660937168, name='', grad='0.0'), Value(data=0.4490096477507219, op='sigmoid', id=4660937808, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4660939088, name='', grad='0.0'), Value(data=1, op='leaf', id=4660939216, name='', grad='0.0')]
# [Value(data=0.24689932717768512, op='sigmoid', id=4660939856, name='', grad='0.0'), Value(data=0.5663363863276336, op='sigmoid', id=4660940496, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660941776, name='', grad='0.0'), Value(data=0, op='leaf', id=4660941904, name='', grad='0.0')]
# [Value(data=0.39047395054165507, op='sigmoid', id=4660942544, name='', grad='0.0'), Value(data=0.5861480153129582, op='sigmoid', id=4660943184, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660944336, name='', grad='0.0'), Value(data=1, op='leaf', id=4660944464, name='', grad='0.0')]
# [Value(data=0.19885229194528778, op='sigmoid', id=4660945104, name='', grad='0.0'), Value(data=0.6938988066564614, op='sigmoid', id=4660945744, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4660947024, name='', grad='0.0'), Value(data=0, op='leaf', id=4660947152, name='', grad='0.0')]
# [Value(data=0.4596997976340312, op='sigmoid', id=4660947792, name='', grad='0.0'), Value(data=0.44800286614667545, op='sigmoid', id=4660948432, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4660949712, name='', grad='0.0'), Value(data=1, op='leaf', id=4660949840, name='', grad='0.0')]
# [Value(data=0.24792423740269132, op='sigmoid', id=4660950480, name='', grad='0.0'), Value(data=0.5650303557015675, op='sigmoid', id=4660951120, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660952400, name='', grad='0.0'), Value(data=0, op='leaf', id=4660952528, name='', grad='0.0')]
# [Value(data=0.39096103760476825, op='sigmoid', id=4661756112, name='', grad='0.0'), Value(data=0.5855911609979108, op='sigmoid', id=4661756752, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661757904, name='', grad='0.0'), Value(data=1, op='leaf', id=4661758032, name='', grad='0.0')]
# [Value(data=0.19930855701194444, op='sigmoid', id=4661758672, name='', grad='0.0'), Value(data=0.6931671124958817, op='sigmoid', id=4661759312, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661760592, name='', grad='0.0'), Value(data=0, op='leaf', id=4661760720, name='', grad='0.0')]
# [Value(data=0.46078181527914, op='sigmoid', id=4661761360, name='', grad='0.0'), Value(data=0.44709340939188724, op='sigmoid', id=4661762000, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661763280, name='', grad='0.0'), Value(data=1, op='leaf', id=4661763408, name='', grad='0.0')]
# [Value(data=0.24888967870894943, op='sigmoid', id=4661764048, name='', grad='0.0'), Value(data=0.5638439595348034, op='sigmoid', id=4661764688, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661765968, name='', grad='0.0'), Value(data=0, op='leaf', id=4661766096, name='', grad='0.0')]
# [Value(data=0.3914084206893545, op='sigmoid', id=4661766736, name='', grad='0.0'), Value(data=0.5850884803749123, op='sigmoid', id=4661767376, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661768528, name='', grad='0.0'), Value(data=1, op='leaf', id=4661768656, name='', grad='0.0')]
# [Value(data=0.19972930614346282, op='sigmoid', id=4661769296, name='', grad='0.0'), Value(data=0.6925016617401363, op='sigmoid', id=4661769936, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661771216, name='', grad='0.0'), Value(data=0, op='leaf', id=4661771344, name='', grad='0.0')]
# [Value(data=0.4617990789583004, op='sigmoid', id=4661771984, name='', grad='0.0'), Value(data=0.4462738630421776, op='sigmoid', id=4661821904, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661823184, name='', grad='0.0'), Value(data=1, op='leaf', id=4661823312, name='', grad='0.0')]
# [Value(data=0.2497973703607982, op='sigmoid', id=4661758928, name='', grad='0.0'), Value(data=0.5627685469770428, op='sigmoid', id=4661758160, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661760336, name='', grad='0.0'), Value(data=0, op='leaf', id=4661756368, name='', grad='0.0')]
# [Value(data=0.391817751426233, op='sigmoid', id=4661757008, name='', grad='0.0'), Value(data=0.5846359055694891, op='sigmoid', id=4661757264, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661760848, name='', grad='0.0'), Value(data=1, op='leaf', id=4661761104, name='', grad='0.0')]
# [Value(data=0.2001158228798226, op='sigmoid', id=4661761616, name='', grad='0.0'), Value(data=0.6918977315587421, op='sigmoid', id=4661762384, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661763280, name='', grad='0.0'), Value(data=0, op='leaf', id=4661764176, name='', grad='0.0')]
# [Value(data=0.4627542282150209, op='sigmoid', id=4661763664, name='', grad='0.0'), Value(data=0.4455372369524143, op='sigmoid', id=4661764816, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661376720, name='', grad='0.0'), Value(data=1, op='leaf', id=4661279824, name='', grad='0.0')]
# [Value(data=0.25064928522251706, op='sigmoid', id=4661265616, name='', grad='0.0'), Value(data=0.5617958842306283, op='sigmoid', id=4661266000, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661269328, name='', grad='0.0'), Value(data=0, op='leaf', id=4661268560, name='', grad='0.0')]
# [Value(data=0.39219076044563245, op='sigmoid', id=4661267920, name='', grad='0.0'), Value(data=0.5842296010066775, op='sigmoid', id=4661268176, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661280208, name='', grad='0.0'), Value(data=1, op='leaf', id=4661280464, name='', grad='0.0')]
# [Value(data=0.2004694926746922, op='sigmoid', id=4661271632, name='', grad='0.0'), Value(data=0.6913508286952301, op='sigmoid', id=4661271376, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661269968, name='', grad='0.0'), Value(data=0, op='leaf', id=4661269584, name='', grad='0.0')]
# [Value(data=0.46365004480310434, op='sigmoid', id=4661823440, name='', grad='0.0'), Value(data=0.4448769802101629, op='sigmoid', id=4661824080, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661825360, name='', grad='0.0'), Value(data=1, op='leaf', id=4661825488, name='', grad='0.0')]
# [Value(data=0.25144758319150734, op='sigmoid', id=4661826128, name='', grad='0.0'), Value(data=0.5609181901379835, op='sigmoid', id=4661826768, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661828048, name='', grad='0.0'), Value(data=0, op='leaf', id=4661828176, name='', grad='0.0')]
# [Value(data=0.39252922244421945, op='sigmoid', id=4661828816, name='', grad='0.0'), Value(data=0.5838659701459934, op='sigmoid', id=4661829456, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661830608, name='', grad='0.0'), Value(data=1, op='leaf', id=4661830736, name='', grad='0.0')]
# [Value(data=0.20079176902233806, op='sigmoid', id=4661831376, name='', grad='0.0'), Value(data=0.690856706363876, op='sigmoid', id=4661832016, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661833296, name='', grad='0.0'), Value(data=0, op='leaf', id=4661833424, name='', grad='0.0')]
# [Value(data=0.46448939332889533, op='sigmoid', id=4661834064, name='', grad='0.0'), Value(data=0.4442869835031013, op='sigmoid', id=4661834704, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661835984, name='', grad='0.0'), Value(data=1, op='leaf', id=4661836112, name='', grad='0.0')]
# [Value(data=0.25219455343977515, op='sigmoid', id=4661836752, name='', grad='0.0'), Value(data=0.5601281542197775, op='sigmoid', id=4661837392, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661707728, name='', grad='0.0'), Value(data=0, op='leaf', id=4661707856, name='', grad='0.0')]
# [Value(data=0.3928349272125746, op='sigmoid', id=4661708496, name='', grad='0.0'), Value(data=0.5835416559043908, op='sigmoid', id=4661709136, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661710288, name='', grad='0.0'), Value(data=1, op='leaf', id=4661710416, name='', grad='0.0')]
# [Value(data=0.2010841447154714, op='sigmoid', id=4661711056, name='', grad='0.0'), Value(data=0.6904113724182935, op='sigmoid', id=4661711696, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661712976, name='', grad='0.0'), Value(data=0, op='leaf', id=4661713104, name='', grad='0.0')]
# [Value(data=0.46527517196216944, op='sigmoid', id=4661713744, name='', grad='0.0'), Value(data=0.4437615720774594, op='sigmoid', id=4661714384, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661715664, name='', grad='0.0'), Value(data=1, op='leaf', id=4661715792, name='', grad='0.0')]
# [Value(data=0.25289256519022046, op='sigmoid', id=4661716432, name='', grad='0.0'), Value(data=0.5594189411096583, op='sigmoid', id=4661717072, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661718352, name='', grad='0.0'), Value(data=0, op='leaf', id=4661718480, name='', grad='0.0')]
# [Value(data=0.39310965605990866, op='sigmoid', id=4661719120, name='', grad='0.0'), Value(data=0.5832535363690882, op='sigmoid', id=4661376848, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661268560, name='', grad='0.0'), Value(data=1, op='leaf', id=4661268944, name='', grad='0.0')]
# [Value(data=0.20134812787979964, op='sigmoid', id=4661268176, name='', grad='0.0'), Value(data=0.6900110907737304, op='sigmoid', id=4661268432, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661280592, name='', grad='0.0'), Value(data=0, op='leaf', id=4661280208, name='', grad='0.0')]
# [Value(data=0.46601027226520064, op='sigmoid', id=4661270736, name='', grad='0.0'), Value(data=0.44329549191464024, op='sigmoid', id=4661271376, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661265744, name='', grad='0.0'), Value(data=1, op='leaf', id=4661266768, name='', grad='0.0')]
# [Value(data=0.2535440264765452, op='sigmoid', id=4661265232, name='', grad='0.0'), Value(data=0.5587841847519546, op='sigmoid', id=4661266384, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661835984, name='', grad='0.0'), Value(data=0, op='leaf', id=4661836880, name='', grad='0.0')]
# [Value(data=0.393355163015469, op='sigmoid', id=4661836240, name='', grad='0.0'), Value(data=0.5829987171241979, op='sigmoid', id=4661837520, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661834960, name='', grad='0.0'), Value(data=1, op='leaf', id=4661833680, name='', grad='0.0')]
# [Value(data=0.20158522234010984, op='sigmoid', id=4661834832, name='', grad='0.0'), Value(data=0.689652377761105, op='sigmoid', id=4661835728, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661831632, name='', grad='0.0'), Value(data=0, op='leaf', id=4661831504, name='', grad='0.0')]
# [Value(data=0.4666975470924402, op='sigmoid', id=4661832400, name='', grad='0.0'), Value(data=0.4428838912548771, op='sigmoid', id=4661830224, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661828432, name='', grad='0.0'), Value(data=1, op='leaf', id=4661828560, name='', grad='0.0')]
# [Value(data=0.25415135017222934, op='sigmoid', id=4661829968, name='', grad='0.0'), Value(data=0.5582179751558799, op='sigmoid', id=4661835856, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661824464, name='', grad='0.0'), Value(data=0, op='leaf', id=4661824592, name='', grad='0.0')]
# [Value(data=0.39357316017783367, op='sigmoid', id=4661827536, name='', grad='0.0'), Value(data=0.5827745212592851, op='sigmoid', id=4661826512, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661826896, name='', grad='0.0'), Value(data=1, op='leaf', id=4661827152, name='', grad='0.0')]
# [Value(data=0.20179691183195322, op='sigmoid', id=4661827920, name='', grad='0.0'), Value(data=0.6893319947986002, op='sigmoid', id=4661763280, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661763664, name='', grad='0.0'), Value(data=0, op='leaf', id=4661765072, name='', grad='0.0')]
# [Value(data=0.4673397854993344, op='sigmoid', id=4661763152, name='', grad='0.0'), Value(data=0.4425222991518361, op='sigmoid', id=4661762128, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661762768, name='', grad='0.0'), Value(data=1, op='leaf', id=4661762896, name='', grad='0.0')]
# [Value(data=0.2547169264966965, op='sigmoid', id=4661756368, name='', grad='0.0'), Value(data=0.5577148399693446, op='sigmoid', id=4661756752, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661757776, name='', grad='0.0'), Value(data=0, op='leaf', id=4661760464, name='', grad='0.0')]
# [Value(data=0.3937653066077635, op='sigmoid', id=4661760080, name='', grad='0.0'), Value(data=0.5825784779026422, op='sigmoid', id=4661758288, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661759440, name='', grad='0.0'), Value(data=1, op='leaf', id=4661759824, name='', grad='0.0')]
# [Value(data=0.20198464756789303, op='sigmoid', id=4661718096, name='', grad='0.0'), Value(data=0.6890469385005085, op='sigmoid', id=4661713872, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661714512, name='', grad='0.0'), Value(data=0, op='leaf', id=4661714768, name='', grad='0.0')]
# [Value(data=0.46793969364029914, op='sigmoid', id=4661712464, name='', grad='0.0'), Value(data=0.44220660235953924, op='sigmoid', id=4661711440, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661712080, name='', grad='0.0'), Value(data=1, op='leaf', id=4661712208, name='', grad='0.0')]
# [Value(data=0.25524310119102206, op='sigmoid', id=4661707856, name='', grad='0.0'), Value(data=0.5572697226660704, op='sigmoid', id=4661708368, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661709648, name='', grad='0.0'), Value(data=0, op='leaf', id=4661709776, name='', grad='0.0')]
# [Value(data=0.3939332002048215, op='sigmoid', id=4661718224, name='', grad='0.0'), Value(data=0.5824083099300281, op='sigmoid', id=4661707344, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661720400, name='', grad='0.0'), Value(data=1, op='leaf', id=4661720528, name='', grad='0.0')]
# [Value(data=0.20214983868602623, op='sigmoid', id=4661721168, name='', grad='0.0'), Value(data=0.6887944291099868, op='sigmoid', id=4661721808, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661903440, name='', grad='0.0'), Value(data=0, op='leaf', id=4661903568, name='', grad='0.0')]
# [Value(data=0.46849988071124343, op='sigmoid', id=4661904208, name='', grad='0.0'), Value(data=0.4419330215336705, op='sigmoid', id=4661714512, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661712464, name='', grad='0.0'), Value(data=1, op='leaf', id=4661711568, name='', grad='0.0')]
# [Value(data=0.2557321585813216, op='sigmoid', id=4661711056, name='', grad='0.0'), Value(data=0.556877958738094, op='sigmoid', id=4661713872, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661713488, name='', grad='0.0'), Value(data=0, op='leaf', id=4661713616, name='', grad='0.0')]
# [Value(data=0.39407837206318413, op='sigmoid', id=4661712080, name='', grad='0.0'), Value(data=0.5822619213402005, op='sigmoid', id=4661708496, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661708880, name='', grad='0.0'), Value(data=1, op='leaf', id=4661709008, name='', grad='0.0')]
# [Value(data=0.20229384514196888, op='sigmoid', id=4661757904, name='', grad='0.0'), Value(data=0.6885718979442639, op='sigmoid', id=4661758288, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661758160, name='', grad='0.0'), Value(data=0, op='leaf', id=4661758416, name='', grad='0.0')]
# [Value(data=0.4690228490854114, op='sigmoid', id=4661760208, name='', grad='0.0'), Value(data=0.44169808746919464, op='sigmoid', id=4661763280, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661765584, name='', grad='0.0'), Value(data=1, op='leaf', id=4661763664, name='', grad='0.0')]
# [Value(data=0.25618630879978177, op='sigmoid', id=4661761488, name='', grad='0.0'), Value(data=0.5565352509511523, op='sigmoid', id=4661762128, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661762896, name='', grad='0.0'), Value(data=0, op='leaf', id=4661760336, name='', grad='0.0')]
# [Value(data=0.39420228286135733, op='sigmoid', id=4661756752, name='', grad='0.0'), Value(data=0.5821373846591074, op='sigmoid', id=4661760720, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661376720, name='', grad='0.0'), Value(data=1, op='leaf', id=4661376848, name='', grad='0.0')]
# [Value(data=0.20241797264695463, op='sigmoid', id=4661272272, name='', grad='0.0'), Value(data=0.688376974376391, op='sigmoid', id=4661268688, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661269072, name='', grad='0.0'), Value(data=0, op='leaf', id=4661268176, name='', grad='0.0')]
# [Value(data=0.46951098789149237, op='sigmoid', id=4661266640, name='', grad='0.0'), Value(data=0.44149861788870653, op='sigmoid', id=4661269840, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661271504, name='', grad='0.0'), Value(data=1, op='leaf', id=4661271376, name='', grad='0.0')]
# [Value(data=0.25660767849959104, op='sigmoid', id=4661270608, name='', grad='0.0'), Value(data=0.556237644447772, op='sigmoid', id=4661266768, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661265616, name='', grad='0.0'), Value(data=0, op='leaf', id=4661266512, name='', grad='0.0')]
# [Value(data=0.3943063208994322, op='sigmoid', id=4661279696, name='', grad='0.0'), Value(data=0.5820329286314379, op='sigmoid', id=4661823184, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661824464, name='', grad='0.0'), Value(data=1, op='leaf', id=4661825488, name='', grad='0.0')]
# [Value(data=0.2025234692993443, op='sigmoid', id=4661824976, name='', grad='0.0'), Value(data=0.6882074727437915, op='sigmoid', id=4661826640, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661832656, name='', grad='0.0'), Value(data=0, op='leaf', id=4661832912, name='', grad='0.0')]
# [Value(data=0.4699665693824576, op='sigmoid', id=4661831888, name='', grad='0.0'), Value(data=0.4413316951334832, op='sigmoid', id=4661828048, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661835344, name='', grad='0.0'), Value(data=1, op='leaf', id=4661835600, name='', grad='0.0')]
# [Value(data=0.2569983044725525, op='sigmoid', id=4661833936, name='', grad='0.0'), Value(data=0.5559815022648295, op='sigmoid', id=4661830608, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661836752, name='', grad='0.0'), Value(data=0, op='leaf', id=4661837520, name='', grad='0.0')]
# [Value(data=0.39439180145330754, op='sigmoid', id=4661837648, name='', grad='0.0'), Value(data=0.5819469263774545, op='sigmoid', id=4661834192, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661830480, name='', grad='0.0'), Value(data=1, op='leaf', id=4661833168, name='', grad='0.0')]
# [Value(data=0.2026115236014438, op='sigmoid', id=4661829584, name='', grad='0.0'), Value(data=0.6880613794668152, op='sigmoid', id=4661823568, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661904720, name='', grad='0.0'), Value(data=0, op='leaf', id=4661904848, name='', grad='0.0')]
# [Value(data=0.47039174753774493, op='sigmoid', id=4661905488, name='', grad='0.0'), Value(data=0.4411946449843397, op='sigmoid', id=4661906128, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661907408, name='', grad='0.0'), Value(data=1, op='leaf', id=4661907536, name='', grad='0.0')]
# [Value(data=0.25736012965130683, op='sigmoid', id=4661908176, name='', grad='0.0'), Value(data=0.5557634816609539, op='sigmoid', id=4661908816, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661910096, name='', grad='0.0'), Value(data=0, op='leaf', id=4661910224, name='', grad='0.0')]
# [Value(data=0.39445996716637693, op='sigmoid', id=4661835856, name='', grad='0.0'), Value(data=0.5818778841308174, op='sigmoid', id=4661829968, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661836112, name='', grad='0.0'), Value(data=1, op='leaf', id=4661837008, name='', grad='0.0')]
# [Value(data=0.20268326359602132, op='sigmoid', id=4661836240, name='', grad='0.0'), Value(data=0.6879368405762127, op='sigmoid', id=4661837264, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661830096, name='', grad='0.0'), Value(data=0, op='leaf', id=4661833680, name='', grad='0.0')]
# [Value(data=0.4707885584275674, op='sigmoid', id=4661832400, name='', grad='0.0'), Value(data=0.4410850167451183, op='sigmoid', id=4661833040, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661825872, name='', grad='0.0'), Value(data=1, op='leaf', id=4661827152, name='', grad='0.0')]
# [Value(data=0.25769500104822773, op='sigmoid', id=4661827408, name='', grad='0.0'), Value(data=0.5555805115165832, op='sigmoid', id=4661826384, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661826256, name='', grad='0.0'), Value(data=0, op='leaf', id=4661825360, name='', grad='0.0')]
# [Value(data=0.39451198924480985, op='sigmoid', id=4661825616, name='', grad='0.0'), Value(data=0.5818244306260014, op='sigmoid', id=4661831504, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661831248, name='', grad='0.0'), Value(data=1, op='leaf', id=4661830736, name='', grad='0.0')]
# [Value(data=0.20273975689609058, op='sigmoid', id=4661830864, name='', grad='0.0'), Value(data=0.6878321497830616, op='sigmoid', id=4661836880, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661265232, name='', grad='0.0'), Value(data=0, op='leaf', id=4661266256, name='', grad='0.0')]
# [Value(data=0.4711589219450553, op='sigmoid', id=4661267152, name='', grad='0.0'), Value(data=0.44100056465184423, op='sigmoid', id=4661269840, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661270736, name='', grad='0.0'), Value(data=1, op='leaf', id=4661271248, name='', grad='0.0')]
# [Value(data=0.2580046692480538, op='sigmoid', id=4661269968, name='', grad='0.0'), Value(data=0.5554297709686056, op='sigmoid', id=4661269712, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661270992, name='', grad='0.0'), Value(data=0, op='leaf', id=4661271504, name='', grad='0.0')]
# [Value(data=0.3945489692625506, op='sigmoid', id=4661279952, name='', grad='0.0'), Value(data=0.5817853071688828, op='sigmoid', id=4661270224, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661266896, name='', grad='0.0'), Value(data=1, op='leaf', id=4661266128, name='', grad='0.0')]
# [Value(data=0.202782011416804, op='sigmoid', id=4661757392, name='', grad='0.0'), Value(data=0.687745737174702, op='sigmoid', id=4661756496, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661757648, name='', grad='0.0'), Value(data=0, op='leaf', id=4661764432, name='', grad='0.0')]
# [Value(data=0.4715046445793623, op='sigmoid', id=4661764176, name='', grad='0.0'), Value(data=0.4409392306200558, op='sigmoid', id=4661758672, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661760080, name='', grad='0.0'), Value(data=1, op='leaf', id=4661760464, name='', grad='0.0')]
# [Value(data=0.2582907891300649, op='sigmoid', id=4661760592, name='', grad='0.0'), Value(data=0.5553086693660665, op='sigmoid', id=4661764304, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661765840, name='', grad='0.0'), Value(data=0, op='leaf', id=4661763152, name='', grad='0.0')]
# [Value(data=0.39457194141672186, op='sigmoid', id=4661760848, name='', grad='0.0'), Value(data=0.5817593583985549, op='sigmoid', id=4661761872, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661709392, name='', grad='0.0'), Value(data=1, op='leaf', id=4661709520, name='', grad='0.0')]
# [Value(data=0.20281097664948272, op='sigmoid', id=4661709904, name='', grad='0.0'), Value(data=0.6876761585826623, op='sigmoid', id=4661713744, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661708624, name='', grad='0.0'), Value(data=0, op='leaf', id=4661715024, name='', grad='0.0')]
# [Value(data=0.471827422961072, op='sigmoid', id=4661710288, name='', grad='0.0'), Value(data=0.44089912830721356, op='sigmoid', id=4661714896, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661711056, name='', grad='0.0'), Value(data=1, op='leaf', id=4661714256, name='', grad='0.0')]
# [Value(data=0.2585549215477239, op='sigmoid', id=4661713872, name='', grad='0.0'), Value(data=0.555214827578047, op='sigmoid', id=4661714640, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661905488, name='', grad='0.0'), Value(data=0, op='leaf', id=4661906256, name='', grad='0.0')]
# [Value(data=0.3945818751036047, op='sigmoid', id=4661906128, name='', grad='0.0'), Value(data=0.5817455237303237, op='sigmoid', id=4661907024, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661910480, name='', grad='0.0'), Value(data=1, op='leaf', id=4661910608, name='', grad='0.0')]
# [Value(data=0.20282754534498434, op='sigmoid', id=4661911248, name='', grad='0.0'), Value(data=0.6876220856407744, op='sigmoid', id=4661911888, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661913168, name='', grad='0.0'), Value(data=0, op='leaf', id=4661913296, name='', grad='0.0')]
# [Value(data=0.472128847960924, op='sigmoid', id=4661376208, name='', grad='0.0'), Value(data=0.44087852844291703, op='sigmoid', id=4661271504, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661270224, name='', grad='0.0'), Value(data=1, op='leaf', id=4661270608, name='', grad='0.0')]
# [Value(data=0.2587985357392533, op='sigmoid', id=4661266384, name='', grad='0.0'), Value(data=0.5551460606451221, op='sigmoid', id=4661270736, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661269968, name='', grad='0.0'), Value(data=0, op='leaf', id=4661269584, name='', grad='0.0')]
# [Value(data=0.39457967771030256, op='sigmoid', id=4661269328, name='', grad='0.0'), Value(data=0.5817428294573874, op='sigmoid', id=4661280464, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661280336, name='', grad='0.0'), Value(data=1, op='leaf', id=4661267408, name='', grad='0.0')]
# [Value(data=0.2028325554970233, op='sigmoid', id=4661271760, name='', grad='0.0'), Value(data=0.6875822965315908, op='sigmoid', id=4661269200, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661273680, name='', grad='0.0'), Value(data=0, op='leaf', id=4661273168, name='', grad='0.0')]
# [Value(data=0.47241040916483845, op='sigmoid', id=4661274960, name='', grad='0.0'), Value(data=0.4408758453640813, op='sigmoid', id=4661275472, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661278544, name='', grad='0.0'), Value(data=1, op='leaf', id=4661277648, name='', grad='0.0')]
# [Value(data=0.25902301228195584, op='sigmoid', id=4661276624, name='', grad='0.0'), Value(data=0.5551003617381782, op='sigmoid', id=4661277264, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661279312, name='', grad='0.0'), Value(data=0, op='leaf', id=4661279184, name='', grad='0.0')]
# [Value(data=0.3945661975380786, op='sigmoid', id=4661906896, name='', grad='0.0'), Value(data=0.5817503814805731, op='sigmoid', id=4661905360, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661907792, name='', grad='0.0'), Value(data=1, op='leaf', id=4661908560, name='', grad='0.0')]
# [Value(data=0.20282679253603092, op='sigmoid', id=4661908176, name='', grad='0.0'), Value(data=0.6875556674050598, op='sigmoid', id=4661909456, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661913680, name='', grad='0.0'), Value(data=0, op='leaf', id=4661913808, name='', grad='0.0')]
# [Value(data=0.47267349958338306, op='sigmoid', id=4661914448, name='', grad='0.0'), Value(data=0.44088962468303766, op='sigmoid', id=4661915088, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661916496, name='', grad='0.0'), Value(data=1, op='leaf', id=4661916624, name='', grad='0.0')]
# [Value(data=0.25922964643674395, op='sigmoid', id=4661917264, name='', grad='0.0'), Value(data=0.555075887369906, op='sigmoid', id=4661917904, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661919184, name='', grad='0.0'), Value(data=0, op='leaf', id=4661919312, name='', grad='0.0')]
# [Value(data=0.39454222679074274, op='sigmoid', id=4660937040, name='', grad='0.0'), Value(data=0.5817673586305642, op='sigmoid', id=4660937680, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660938832, name='', grad='0.0'), Value(data=1, op='leaf', id=4660938960, name='', grad='0.0')]
# [Value(data=0.20281099166105293, op='sigmoid', id=4660939600, name='', grad='0.0'), Value(data=0.6875411644438114, op='sigmoid', id=4660940240, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4660941520, name='', grad='0.0'), Value(data=0, op='leaf', id=4660941648, name='', grad='0.0')]
# [Value(data=0.4729194204830745, op='sigmoid', id=4660942288, name='', grad='0.0'), Value(data=0.4409185320120039, op='sigmoid', id=4660942928, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4660944208, name='', grad='0.0'), Value(data=1, op='leaf', id=4660944336, name='', grad='0.0')]
# [Value(data=0.2594196517578958, op='sigmoid', id=4660944976, name='', grad='0.0'), Value(data=0.555070943792724, op='sigmoid', id=4660945616, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660946896, name='', grad='0.0'), Value(data=0, op='leaf', id=4660947024, name='', grad='0.0')]
# [Value(data=0.39450850457582454, op='sigmoid', id=4660947664, name='', grad='0.0'), Value(data=0.5817930065444923, op='sigmoid', id=4660948304, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660949456, name='', grad='0.0'), Value(data=1, op='leaf', id=4660949584, name='', grad='0.0')]
# [Value(data=0.20278584025138968, op='sigmoid', id=4660950224, name='', grad='0.0'), Value(data=0.6875378365432333, op='sigmoid', id=4660950864, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4660952144, name='', grad='0.0'), Value(data=0, op='leaf', id=4660952272, name='', grad='0.0')]
# [Value(data=0.4731493862510742, op='sigmoid', id=4660952912, name='', grad='0.0'), Value(data=0.44096134266618237, op='sigmoid', id=4661789264, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661790544, name='', grad='0.0'), Value(data=1, op='leaf', id=4661790672, name='', grad='0.0')]
# [Value(data=0.25959416386711015, op='sigmoid', id=4661791312, name='', grad='0.0'), Value(data=0.5550839745104152, op='sigmoid', id=4661791952, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661793232, name='', grad='0.0'), Value(data=0, op='leaf', id=4661793360, name='', grad='0.0')]
# [Value(data=0.3944657198780749, op='sigmoid', id=4661919440, name='', grad='0.0'), Value(data=0.5818266320578955, op='sigmoid', id=4661917008, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661918160, name='', grad='0.0'), Value(data=1, op='leaf', id=4661918288, name='', grad='0.0')]
# [Value(data=0.2027519803115589, op='sigmoid', id=4661918928, name='', grad='0.0'), Value(data=0.6875448085709059, op='sigmoid', id=4661914576, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661915216, name='', grad='0.0'), Value(data=0, op='leaf', id=4661915472, name='', grad='0.0')]
# [Value(data=0.4733645292247014, op='sigmoid', id=4661904080, name='', grad='0.0'), Value(data=0.4410169322688839, op='sigmoid', id=4661909200, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661903824, name='', grad='0.0'), Value(data=1, op='leaf', id=4661903568, name='', grad='0.0')]
# [Value(data=0.25975424431108, op='sigmoid', id=4661904848, name='', grad='0.0'), Value(data=0.5551135488279947, op='sigmoid', id=4661905104, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661916368, name='', grad='0.0'), Value(data=0, op='leaf', id=4661919056, name='', grad='0.0')]
# [Value(data=0.3944145144744794, op='sigmoid', id=4661376208, name='', grad='0.0'), Value(data=0.581867598073387, op='sigmoid', id=4661277520, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661278032, name='', grad='0.0'), Value(data=1, op='leaf', id=4661277904, name='', grad='0.0')]
# [Value(data=0.20271001091301907, op='sigmoid', id=4661276752, name='', grad='0.0'), Value(data=0.6875612751682396, op='sigmoid', id=4661276880, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661267536, name='', grad='0.0'), Value(data=0, op='leaf', id=4661267280, name='', grad='0.0')]
# [Value(data=0.4735659044334055, op='sigmoid', id=4661272784, name='', grad='0.0'), Value(data=0.4410842681847847, op='sigmoid', id=4661269584, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661268304, name='', grad='0.0'), Value(data=1, op='leaf', id=4661267664, name='', grad='0.0')]
# [Value(data=0.25990088443857456, op='sigmoid', id=4661279568, name='', grad='0.0'), Value(data=0.5551583513642055, op='sigmoid', id=4661275728, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661275856, name='', grad='0.0'), Value(data=0, op='leaf', id=4661273936, name='', grad='0.0')]
# [Value(data=0.3943554857678043, op='sigmoid', id=4661276240, name='', grad='0.0'), Value(data=0.5819153188685361, op='sigmoid', id=4661279440, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661268688, name='', grad='0.0'), Value(data=1, op='leaf', id=4661265488, name='', grad='0.0')]
# [Value(data=0.20266049060424215, op='sigmoid', id=4661269456, name='', grad='0.0'), Value(data=0.6875864950567829, op='sigmoid', id=4661268048, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661279952, name='', grad='0.0'), Value(data=0, op='leaf', id=4661270864, name='', grad='0.0')]
# [Value(data=0.473754494214026, op='sigmoid', id=4661792720, name='', grad='0.0'), Value(data=0.4411624017111279, op='sigmoid', id=4661788752, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661790288, name='', grad='0.0'), Value(data=1, op='leaf', id=4661790416, name='', grad='0.0')]
# [Value(data=0.26003500924691664, op='sigmoid', id=4661794000, name='', grad='0.0'), Value(data=0.5552171724527507, op='sigmoid', id=4661794640, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661795920, name='', grad='0.0'), Value(data=0, op='leaf', id=4661796048, name='', grad='0.0')]
# [Value(data=0.3942891895220208, op='sigmoid', id=4661796688, name='', grad='0.0'), Value(data=0.5819692558071672, op='sigmoid', id=4661797328, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661798480, name='', grad='0.0'), Value(data=1, op='leaf', id=4661798608, name='', grad='0.0')]
# [Value(data=0.20260393976742141, op='sigmoid', id=4661799248, name='', grad='0.0'), Value(data=0.6876197858122637, op='sigmoid', id=4661799888, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661801168, name='', grad='0.0'), Value(data=0, op='leaf', id=4661801296, name='', grad='0.0')]
# [Value(data=0.473931212670817, op='sigmoid', id=4661801936, name='', grad='0.0'), Value(data=0.4412504609609808, op='sigmoid', id=4661802576, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661803856, name='', grad='0.0'), Value(data=1, op='leaf', id=4661803984, name='', grad='0.0')]
# [Value(data=0.260157481159199, op='sigmoid', id=4661804624, name='', grad='0.0'), Value(data=0.555288899361301, op='sigmoid', id=4661707088, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661708368, name='', grad='0.0'), Value(data=0, op='leaf', id=4661708496, name='', grad='0.0')]
# [Value(data=0.39421614248803916, op='sigmoid', id=4661709136, name='', grad='0.0'), Value(data=0.5820289134203005, op='sigmoid', id=4661709776, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661710928, name='', grad='0.0'), Value(data=1, op='leaf', id=4661711056, name='', grad='0.0')]
# [Value(data=0.2025408429055808, op='sigmoid', id=4661711696, name='', grad='0.0'), Value(data=0.6876605190706555, op='sigmoid', id=4661712336, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661713616, name='', grad='0.0'), Value(data=0, op='leaf', id=4661713744, name='', grad='0.0')]
# [Value(data=0.47409690996027115, op='sigmoid', id=4661376976, name='', grad='0.0'), Value(data=0.4413476443772336, op='sigmoid', id=4661279952, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661275600, name='', grad='0.0'), Value(data=1, op='leaf', id=4661276240, name='', grad='0.0')]
# [Value(data=0.26026910370297446, op='sigmoid', id=4661277776, name='', grad='0.0'), Value(data=0.555372508261025, op='sigmoid', id=4661265360, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661269456, name='', grad='0.0'), Value(data=0, op='leaf', id=4661265744, name='', grad='0.0')]
# [Value(data=0.394136824912238, op='sigmoid', id=4661268048, name='', grad='0.0'), Value(data=0.582093835825169, op='sigmoid', id=4661270480, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661273040, name='', grad='0.0'), Value(data=1, op='leaf', id=4661275728, name='', grad='0.0')]
# [Value(data=0.2024716508483081, op='sigmoid', id=4661264976, name='', grad='0.0'), Value(data=0.6877081161322341, op='sigmoid', id=4661275088, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661273552, name='', grad='0.0'), Value(data=0, op='leaf', id=4661269584, name='', grad='0.0')]
# [Value(data=0.47425237638760714, op='sigmoid', id=4661272656, name='', grad='0.0'), Value(data=0.441453214820686, op='sigmoid', id=4661267024, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661276752, name='', grad='0.0'), Value(data=1, op='leaf', id=4661273424, name='', grad='0.0')]
# [Value(data=0.2603706250688298, op='sigmoid', id=4661276880, name='', grad='0.0'), Value(data=0.555467056883528, op='sigmoid', id=4661271632, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661278800, name='', grad='0.0'), Value(data=0, op='leaf', id=4661274704, name='', grad='0.0')]
# [Value(data=0.3940516829234824, op='sigmoid', id=4661268560, name='', grad='0.0'), Value(data=0.582163603453003, op='sigmoid', id=4661804752, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661798608, name='', grad='0.0'), Value(data=1, op='leaf', id=4661799504, name='', grad='0.0')]
# [Value(data=0.20239678286794174, op='sigmoid', id=4661798736, name='', grad='0.0'), Value(data=0.6877620439315028, op='sigmoid', id=4661800016, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661796816, name='', grad='0.0'), Value(data=0, op='leaf', id=4661797072, name='', grad='0.0')]
# [Value(data=0.4743983463071957, op='sigmoid', id=4661796176, name='', grad='0.0'), Value(data=0.44156649418015137, op='sigmoid', id=4661797712, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661801680, name='', grad='0.0'), Value(data=1, op='leaf', id=4661801808, name='', grad='0.0')]
# [Value(data=0.2604627415334734, op='sigmoid', id=4661802320, name='', grad='0.0'), Value(data=0.5555716778064302, op='sigmoid', id=4661803088, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661788880, name='', grad='0.0'), Value(data=0, op='leaf', id=4661788752, name='', grad='0.0')]
# [Value(data=0.3939611307968488, op='sigmoid', id=4661789520, name='', grad='0.0'), Value(data=0.5822378300585296, op='sigmoid', id=4661790416, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661794128, name='', grad='0.0'), Value(data=1, op='leaf', id=4661794384, name='', grad='0.0')]
# [Value(data=0.20231662870093955, op='sigmoid', id=4661795152, name='', grad='0.0'), Value(data=0.6878218113429163, op='sigmoid', id=4661795792, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661904208, name='', grad='0.0'), Value(data=0, op='leaf', id=4661908432, name='', grad='0.0')]
# [Value(data=0.47453550182344995, op='sigmoid', id=4661904720, name='', grad='0.0'), Value(data=0.4416868584569209, op='sigmoid', id=4661910352, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661916240, name='', grad='0.0'), Value(data=1, op='leaf', id=4661904080, name='', grad='0.0')]
# [Value(data=0.26054610073699563, op='sigmoid', id=4661909072, name='', grad='0.0'), Value(data=0.5556855723131805, op='sigmoid', id=4661907920, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661916496, name='', grad='0.0'), Value(data=0, op='leaf', id=4661916752, name='', grad='0.0')]
# [Value(data=0.39386555309422605, op='sigmoid', id=4661917520, name='', grad='0.0'), Value(data=0.582316159986323, op='sigmoid', id=4661915984, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661918672, name='', grad='0.0'), Value(data=1, op='leaf', id=4661918800, name='', grad='0.0')]
# [Value(data=0.20223155047146885, op='sigmoid', id=4661913936, name='', grad='0.0'), Value(data=0.6878869657944344, op='sigmoid', id=4661903696, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661707728, name='', grad='0.0'), Value(data=0, op='leaf', id=4661707984, name='', grad='0.0')]
# [Value(data=0.4746644762920157, op='sigmoid', id=4661714640, name='', grad='0.0'), Value(data=0.44181373328011714, op='sigmoid', id=4661715280, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661716560, name='', grad='0.0'), Value(data=1, op='leaf', id=4661716688, name='', grad='0.0')]
# [Value(data=0.26062130480798895, op='sigmoid', id=4661717328, name='', grad='0.0'), Value(data=0.5558080047769858, op='sigmoid', id=4661717968, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661719248, name='', grad='0.0'), Value(data=0, op='leaf', id=4661719376, name='', grad='0.0')]
# [Value(data=0.39376530668347026, op='sigmoid', id=4661918672, name='', grad='0.0'), Value(data=0.5823982656712243, op='sigmoid', id=4661914448, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661916496, name='', grad='0.0'), Value(data=1, op='leaf', id=4661917008, name='', grad='0.0')]
# [Value(data=0.20214188451609127, op='sigmoid', id=4661917520, name='', grad='0.0'), Value(data=0.6879570901630027, op='sigmoid', id=4661918160, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661909200, name='', grad='0.0'), Value(data=0, op='leaf', id=4661904080, name='', grad='0.0')]
# [Value(data=0.47478585762363346, op='sigmoid', id=4661908176, name='', grad='0.0'), Value(data=0.44194658981338075, op='sigmoid', id=4661909072, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661908432, name='', grad='0.0'), Value(data=1, op='leaf', id=4661905104, name='', grad='0.0')]
# [Value(data=0.2606889133334177, op='sigmoid', id=4661904848, name='', grad='0.0'), Value(data=0.5559382975228453, op='sigmoid', id=4661908304, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661907408, name='', grad='0.0'), Value(data=0, op='leaf', id=4661904336, name='', grad='0.0')]
# [Value(data=0.39366072263891283, op='sigmoid', id=4661794128, name='', grad='0.0'), Value(data=0.5824838453520187, op='sigmoid', id=4661795664, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661788752, name='', grad='0.0'), Value(data=1, op='leaf', id=4661792720, name='', grad='0.0')]
# [Value(data=0.20204794310984606, op='sigmoid', id=4661789520, name='', grad='0.0'), Value(data=0.688031799928077, op='sigmoid', id=4661790160, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661801936, name='', grad='0.0'), Value(data=0, op='leaf', id=4661801808, name='', grad='0.0')]
# [Value(data=0.4749001913949629, op='sigmoid', id=4661803216, name='', grad='0.0'), Value(data=0.44208494101697127, op='sigmoid', id=4661803088, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661796816, name='', grad='0.0'), Value(data=1, op='leaf', id=4661796432, name='', grad='0.0')]
# [Value(data=0.26074944617265783, op='sigmoid', id=4661797328, name='', grad='0.0'), Value(data=0.5560758261255793, op='sigmoid', id=4661797840, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661798992, name='', grad='0.0'), Value(data=0, op='leaf', id=4661799120, name='', grad='0.0')]
# [Value(data=0.39355210802686097, op='sigmoid', id=4661799760, name='', grad='0.0'), Value(data=0.5825726209793942, op='sigmoid', id=4661800528, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661804752, name='', grad='0.0'), Value(data=1, op='leaf', id=4661804112, name='', grad='0.0')]
# [Value(data=0.20195001609514499, op='sigmoid', id=4661798480, name='', grad='0.0'), Value(data=0.6881107405612295, op='sigmoid', id=4661376976, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661272400, name='', grad='0.0'), Value(data=0, op='leaf', id=4661268560, name='', grad='0.0')]
# [Value(data=0.4750079837720829, op='sigmoid', id=4661278288, name='', grad='0.0'), Value(data=0.4422283382327101, op='sigmoid', id=4661265616, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661277648, name='', grad='0.0'), Value(data=1, op='leaf', id=4661278032, name='', grad='0.0')]
# [Value(data=0.26080338611709414, op='sigmoid', id=4661265232, name='', grad='0.0'), Value(data=0.5562200151053875, op='sigmoid', id=4661269968, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661273296, name='', grad='0.0'), Value(data=0, op='leaf', id=4661275728, name='', grad='0.0')]
# [Value(data=0.39343974758032, op='sigmoid', id=4661267920, name='', grad='0.0'), Value(data=0.5826643363009066, op='sigmoid', id=4661273168, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661268304, name='', grad='0.0'), Value(data=1, op='leaf', id=4661265744, name='', grad='0.0')]
# [Value(data=0.2018483724157353, op='sigmoid', id=4661272016, name='', grad='0.0'), Value(data=0.6881935851316867, op='sigmoid', id=4661266896, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661277008, name='', grad='0.0'), Value(data=0, op='leaf', id=4661278544, name='', grad='0.0')]
# [Value(data=0.4751097042533889, op='sigmoid', id=4661271120, name='', grad='0.0'), Value(data=0.442376368062258, op='sigmoid', id=4661275472, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4661268944, name='', grad='0.0'), Value(data=1, op='leaf', id=4661276368, name='', grad='0.0')]
# [Value(data=0.26085118139817703, op='sigmoid', id=4661271248, name='', grad='0.0'), Value(data=0.556370333985874, op='sigmoid', id=4661266000, name='', grad='0.0')]
# ...
# [Value(data=1, op='leaf', id=4674174416, name='', grad='0.0'), Value(data=0, op='leaf', id=4674160336, name='', grad='0.0')]
# [Value(data=0.9025508928784536, op='sigmoid', id=4674329808, name='', grad='0.0'), Value(data=0.0015593059760194382, op='sigmoid', id=4674325840, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674330064, name='', grad='0.0'), Value(data=1, op='leaf', id=4674328016, name='', grad='0.0')]
# [Value(data=0.031983211412216446, op='sigmoid', id=4674335696, name='', grad='0.0'), Value(data=0.076471034831463, op='sigmoid', id=4674326992, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4673666896, name='', grad='0.0'), Value(data=0, op='leaf', id=4673660752, name='', grad='0.0')]
# [Value(data=0.030115153812240194, op='sigmoid', id=4660431824, name='', grad='0.0'), Value(data=0.10205732877923995, op='sigmoid', id=4660436944, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4674619344, name='', grad='0.0'), Value(data=1, op='leaf', id=4674632272, name='', grad='0.0')]
# [Value(data=0.00011072732981385093, op='sigmoid', id=4674633296, name='', grad='0.0'), Value(data=0.8577437178951162, op='sigmoid', id=4674622416, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674629200, name='', grad='0.0'), Value(data=0, op='leaf', id=4674629840, name='', grad='0.0')]
# [Value(data=0.902576226620169, op='sigmoid', id=4674629968, name='', grad='0.0'), Value(data=0.001557861585338133, op='sigmoid', id=4674621904, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674621008, name='', grad='0.0'), Value(data=1, op='leaf', id=4674632016, name='', grad='0.0')]
# [Value(data=0.031984478275887976, op='sigmoid', id=4673556816, name='', grad='0.0'), Value(data=0.07644665012793585, op='sigmoid', id=4661911760, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661910224, name='', grad='0.0'), Value(data=0, op='leaf', id=4661918416, name='', grad='0.0')]
# [Value(data=0.030114952553879873, op='sigmoid', id=4674543440, name='', grad='0.0'), Value(data=0.10202378226484198, op='sigmoid', id=4674543696, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4674550352, name='', grad='0.0'), Value(data=1, op='leaf', id=4674542544, name='', grad='0.0')]
# [Value(data=0.00011069922606206797, op='sigmoid', id=4674547408, name='', grad='0.0'), Value(data=0.8577700893197306, op='sigmoid', id=4674545360, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4673223120, name='', grad='0.0'), Value(data=0, op='leaf', id=4673210704, name='', grad='0.0')]
# [Value(data=0.902601525075203, op='sigmoid', id=4673306320, name='', grad='0.0'), Value(data=0.0015564200144799136, op='sigmoid', id=4673920976, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4660930128, name='', grad='0.0'), Value(data=1, op='leaf', id=4660935504, name='', grad='0.0')]
# [Value(data=0.03198574018340481, op='sigmoid', id=4673469136, name='', grad='0.0'), Value(data=0.0764222980793372, op='sigmoid', id=4673461712, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4673469008, name='', grad='0.0'), Value(data=0, op='leaf', id=4673467984, name='', grad='0.0')]
# [Value(data=0.03011474993327387, op='sigmoid', id=4673468368, name='', grad='0.0'), Value(data=0.10199028203718964, op='sigmoid', id=4673469648, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4673822416, name='', grad='0.0'), Value(data=1, op='leaf', id=4673825744, name='', grad='0.0')]
# [Value(data=0.00011067114338687227, op='sigmoid', id=4673830224, name='', grad='0.0'), Value(data=0.8577964330527611, op='sigmoid', id=4673830480, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674072528, name='', grad='0.0'), Value(data=0, op='leaf', id=4674063952, name='', grad='0.0')]
# [Value(data=0.9026267883217453, op='sigmoid', id=4674074576, name='', grad='0.0'), Value(data=0.0015549812553937424, op='sigmoid', id=4674074832, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674063568, name='', grad='0.0'), Value(data=1, op='leaf', id=4674071888, name='', grad='0.0')]
# [Value(data=0.031986997147287394, op='sigmoid', id=4674074448, name='', grad='0.0'), Value(data=0.07639797861562964, op='sigmoid', id=4674071120, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660944976, name='', grad='0.0'), Value(data=0, op='leaf', id=4660944720, name='', grad='0.0')]
# [Value(data=0.030114545954433216, op='sigmoid', id=4673724880, name='', grad='0.0'), Value(data=0.10195682799296403, op='sigmoid', id=4673725392, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4673725008, name='', grad='0.0'), Value(data=1, op='leaf', id=4673732304, name='', grad='0.0')]
# [Value(data=0.00011064308176631544, op='sigmoid', id=4673731792, name='', grad='0.0'), Value(data=0.857822749145784, op='sigmoid', id=4673134032, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4673126864, name='', grad='0.0'), Value(data=0, op='leaf', id=4673142224, name='', grad='0.0')]
# [Value(data=0.9026520164377556, op='sigmoid', id=4674328912, name='', grad='0.0'), Value(data=0.0015535453000584554, op='sigmoid', id=4674440144, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674446544, name='', grad='0.0'), Value(data=1, op='leaf', id=4674439504, name='', grad='0.0')]
# [Value(data=0.03198824918002125, op='sigmoid', id=4674452304, name='', grad='0.0'), Value(data=0.07637369166697865, op='sigmoid', id=4674451024, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4674449488, name='', grad='0.0'), Value(data=0, op='leaf', id=4674446800, name='', grad='0.0')]
# [Value(data=0.030114340621357004, op='sigmoid', id=4674439248, name='', grad='0.0'), Value(data=0.1019234200291597, op='sigmoid', id=4674448592, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4673990608, name='', grad='0.0'), Value(data=1, op='leaf', id=4673992272, name='', grad='0.0')]
# [Value(data=0.00011061504117846916, op='sigmoid', id=4673987536, name='', grad='0.0'), Value(data=0.8578490376502393, op='sigmoid', id=4673989328, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674330320, name='', grad='0.0'), Value(data=0, op='leaf', id=4674335952, name='', grad='0.0')]
# [Value(data=0.9026772095009642, op='sigmoid', id=4673725008, name='', grad='0.0'), Value(data=0.0015521121404826386, op='sigmoid', id=4673717840, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4673718608, name='', grad='0.0'), Value(data=1, op='leaf', id=4673717456, name='', grad='0.0')]
# [Value(data=0.031989496294057146, op='sigmoid', id=4673142224, name='', grad='0.0'), Value(data=0.07634943716375195, op='sigmoid', id=4673141200, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4674453200, name='', grad='0.0'), Value(data=0, op='leaf', id=4674447952, name='', grad='0.0')]
# [Value(data=0.030114133938032372, op='sigmoid', id=4674439376, name='', grad='0.0'), Value(data=0.10189005804308333, op='sigmoid', id=4674438608, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4674451024, name='', grad='0.0'), Value(data=1, op='leaf', id=4674450896, name='', grad='0.0')]
# [Value(data=0.00011058702160142563, op='sigmoid', id=4674452304, name='', grad='0.0'), Value(data=0.8578752986174305, op='sigmoid', id=4674453072, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4673828816, name='', grad='0.0'), Value(data=0, op='leaf', id=4673830224, name='', grad='0.0')]
# [Value(data=0.9027023675888731, op='sigmoid', id=4673822800, name='', grad='0.0'), Value(data=0.001550681768704485, op='sigmoid', id=4673821648, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674068432, name='', grad='0.0'), Value(data=1, op='leaf', id=4674063568, name='', grad='0.0')]
# [Value(data=0.031990738501811174, op='sigmoid', id=4674062160, name='', grad='0.0'), Value(data=0.07632521503651868, op='sigmoid', id=4674074448, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4674065744, name='', grad='0.0'), Value(data=0, op='leaf', id=4674074832, name='', grad='0.0')]
# [Value(data=0.03011392590843463, op='sigmoid', id=4674069584, name='', grad='0.0'), Value(data=0.10185674193235272, op='sigmoid', id=4674070352, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660942672, name='', grad='0.0'), Value(data=1, op='leaf', id=4660944976, name='', grad='0.0')]
# [Value(data=0.0001105590230132981, op='sigmoid', id=4660938320, name='', grad='0.0'), Value(data=0.8579015320985239, op='sigmoid', id=4661817168, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674541520, name='', grad='0.0'), Value(data=0, op='leaf', id=4674550352, name='', grad='0.0')]
# [Value(data=0.9027274907787566, op='sigmoid', id=4674543952, name='', grad='0.0'), Value(data=0.0015492541767916615, op='sigmoid', id=4674544464, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674544080, name='', grad='0.0'), Value(data=1, op='leaf', id=4674542672, name='', grad='0.0')]
# [Value(data=0.0319919758156648, op='sigmoid', id=4673223120, name='', grad='0.0'), Value(data=0.07630102521604876, op='sigmoid', id=4673216592, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4673388624, name='', grad='0.0'), Value(data=0, op='leaf', id=4673392592, name='', grad='0.0')]
# [Value(data=0.03011371653652723, op='sigmoid', id=4673467984, name='', grad='0.0'), Value(data=0.10182347159489552, op='sigmoid', id=4673469520, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4673468112, name='', grad='0.0'), Value(data=1, op='leaf', id=4673468240, name='', grad='0.0')]
# [Value(data=0.0001105310453922194, op='sigmoid', id=4673467088, name='', grad='0.0'), Value(data=0.8579277381445515, op='sigmoid', id=4673468752, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4660436432, name='', grad='0.0'), Value(data=0, op='leaf', id=4660431824, name='', grad='0.0')]
# [Value(data=0.902752579147662, op='sigmoid', id=4660431056, name='', grad='0.0'), Value(data=0.0015478293568411809, op='sigmoid', id=4674632912, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674630480, name='', grad='0.0'), Value(data=1, op='leaf', id=4674621520, name='', grad='0.0')]
# [Value(data=0.03199320824796507, op='sigmoid', id=4674625360, name='', grad='0.0'), Value(data=0.07627686763331218, op='sigmoid', id=4674622544, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4674623440, name='', grad='0.0'), Value(data=0, op='leaf', id=4674630992, name='', grad='0.0')]
# [Value(data=0.03011350582626184, op='sigmoid', id=4674632784, name='', grad='0.0'), Value(data=0.10179024692894803, op='sigmoid', id=4674623184, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4661908944, name='', grad='0.0'), Value(data=1, op='leaf', id=4661918800, name='', grad='0.0')]
# [Value(data=0.00011050308871634336, op='sigmoid', id=4661911760, name='', grad='0.0'), Value(data=0.8579539168064089, op='sigmoid', id=4661909840, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4673660496, name='', grad='0.0'), Value(data=0, op='leaf', id=4673979472, name='', grad='0.0')]
# [Value(data=0.9027776327724114, op='sigmoid', id=4673992400, name='', grad='0.0'), Value(data=0.0015464073009792626, op='sigmoid', id=4673988688, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4673987792, name='', grad='0.0'), Value(data=1, op='leaf', id=4673987664, name='', grad='0.0')]
# [Value(data=0.03199443581102467, op='sigmoid', id=4673979344, name='', grad='0.0'), Value(data=0.07625274221947806, op='sigmoid', id=4673991888, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660436432, name='', grad='0.0'), Value(data=0, op='leaf', id=4660436944, name='', grad='0.0')]
# [Value(data=0.03011329378157834, op='sigmoid', id=4660431184, name='', grad='0.0'), Value(data=0.1017570678330541, op='sigmoid', id=4673388624, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4673455312, name='', grad='0.0'), Value(data=1, op='leaf', id=4673468752, name='', grad='0.0')]
# [Value(data=0.0001104751529638445, op='sigmoid', id=4673469392, name='', grad='0.0'), Value(data=0.8579800681348576, op='sigmoid', id=4673467984, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4673467216, name='', grad='0.0'), Value(data=0, op='leaf', id=4673468368, name='', grad='0.0')]
# [Value(data=0.9028026517296005, op='sigmoid', id=4673565520, name='', grad='0.0'), Value(data=0.0015449880013612039, op='sigmoid', id=4674629968, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674622672, name='', grad='0.0'), Value(data=1, op='leaf', id=4674622544, name='', grad='0.0')]
# [Value(data=0.031995658517121967, op='sigmoid', id=4674622416, name='', grad='0.0'), Value(data=0.07622864890591438, op='sigmoid', id=4674629584, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660935504, name='', grad='0.0'), Value(data=0, op='leaf', id=4660930128, name='', grad='0.0')]
# [Value(data=0.030113080406404914, op='sigmoid', id=4673306320, name='', grad='0.0'), Value(data=0.10172393420606397, op='sigmoid', id=4673928400, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4660944720, name='', grad='0.0'), Value(data=1, op='leaf', id=4674542672, name='', grad='0.0')]
# [Value(data=0.00011044723811291729, op='sigmoid', id=4674543056, name='', grad='0.0'), Value(data=0.8580061921805247, op='sigmoid', id=4674541520, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674544464, name='', grad='0.0'), Value(data=0, op='leaf', id=4674542416, name='', grad='0.0')]
# [Value(data=0.9028276360956018, op='sigmoid', id=4674542288, name='', grad='0.0'), Value(data=0.0015435714501712487, op='sigmoid', id=4673209936, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4673217744, name='', grad='0.0'), Value(data=1, op='leaf', id=4673214544, name='', grad='0.0')]
# [Value(data=0.03199687637850123, op='sigmoid', id=4674438608, name='', grad='0.0'), Value(data=0.07620458762418673, op='sigmoid', id=4674438480, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4674450000, name='', grad='0.0'), Value(data=0, op='leaf', id=4674450896, name='', grad='0.0')]
# [Value(data=0.030112865704658057, op='sigmoid', id=4674439120, name='', grad='0.0'), Value(data=0.10169084594713299, op='sigmoid', id=4674452304, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4673820752, name='', grad='0.0'), Value(data=1, op='leaf', id=4673828816, name='', grad='0.0')]
# [Value(data=0.00011041934414177739, op='sigmoid', id=4673824720, name='', grad='0.0'), Value(data=0.8580322889939033, op='sigmoid', id=4673825616, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674069072, name='', grad='0.0'), Value(data=0, op='leaf', id=4674074832, name='', grad='0.0')]
# [Value(data=0.9028525859465634, op='sigmoid', id=4674073424, name='', grad='0.0'), Value(data=0.0015421576396224563, op='sigmoid', id=4674065232, name='', grad='0.0')]
# [Value(data=1, op='leaf', id=4674066384, name='', grad='0.0'), Value(data=1, op='leaf', id=4674068432, name='', grad='0.0')]
# [Value(data=0.031998089407372636, op='sigmoid', id=4674073040, name='', grad='0.0'), Value(data=0.07618055830605795, op='sigmoid', id=4674072144, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4674335952, name='', grad='0.0'), Value(data=0, op='leaf', id=4674330320, name='', grad='0.0')]
# [Value(data=0.030112649680242617, op='sigmoid', id=4673731920, name='', grad='0.0'), Value(data=0.1016578029557206, op='sigmoid', id=4673724240, name='', grad='0.0')]
# [Value(data=0, op='leaf', id=4673731792, name='', grad='0.0'), Value(data=1, op='leaf', id=4673724880, name='', grad='0.0')]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 32
#      29 inputs = train_x[i]
#      30 target = train_y[i]
# ---> 32 outputs = mlp(inputs)  # Forward pass
#      33 if overall_loss is None:
#      34     overall_loss = (outputs - target[0]) ** 2  # Mean Squared Error
#
# Cell In[5], line 70, in MLP.__call__(self, *args, **kwargs)
#      69 def __call__(self, *args, **kwargs):
# ---> 70     return self.forward(*args)
#
# Cell In[5], line 65, in MLP.forward(self, mlp_inputs)
#      63 mlp_inputs = [Value(x) if not isinstance(x, Value) else x for x in mlp_inputs]  # Convert inputs to Value objects
#      64 for layer in self.layers:
# ---> 65     print(mlp_inputs)
#      66     mlp_inputs = layer.forward(mlp_inputs)
#      67 return mlp_inputs if len(mlp_inputs) != 1 else mlp_inputs[0]
#
# KeyboardInterrupt:
